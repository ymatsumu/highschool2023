# %%
import numpy as np
import matplotlib.pyplot as plt

x = 0 #make plot to track random value
y = 0


num = 0
for i in range(0, 200, 1): #input from 0 to 200 with step of 200 #run this code for 199 times
    random_distance = np.random.random() #[0,1) #random distance to walk
    
    random_angle = np.random.random() #[0,1)
    random_theta = random_angle * 360 #random angle to change

    x = random_distance * np.cos(random_theta)
    y = random_distance * np.sin(random_theta)

    if (x >= 0 and x <= 1) and (y >= 0 and y <= 1):
        if x > 0.3 and y > 0.3:
            plt.scatter(x,y,c="green")
        else: 
            plt.scatter(x,y, c="#c57f7f")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Random Plot")
#plt.xlim([0,1])
#plt.ylim([0,1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

for i in range(0, 100, 1): #input from 0 to 200 with step of 200 #run this code for 199 times
    random_distance = np.random.random() #[0,1) #random distance to walk
    
    x = random.uniform(0,100)
    y = random.uniform(0,100)

    g = random.randint(0,141)
    f = random.randint(0,141)
    x2 = x + g
    y2 = y + f 
  #figure out how to connect points
    plt.scatter(x2,y2)
    plt.plot(x2,y2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Random Plot")
#plt.xlim([0,1])
#plt.ylim([0,1])
plt.show()

# %%
import random
x = random.randint(0,100)
print(x)
# Out:
# 41
